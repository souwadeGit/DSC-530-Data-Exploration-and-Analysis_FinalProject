# %%
import pandas as pd                     
import matplotlib.pyplot as plt          # plotting
import numpy as np                       # dense matrices
from scipy.sparse import csr_matrix      # sparse matrices
# %matplotlib inline

import numpy as np
df = pd.read_csv("C:/Users/Soukhna/Desktop/DSC530_11252019/My project_DSC530/fusion_GLOBAL_DATAFLOW_UNICEF_1.0_.PT_F_15-49_FGM+PT_M_15-49_FGM_ELIM+PT_F_0-14_FGM+PT_F_15-49_FGM_ELIM.._(1).csv")
#df
#df.columns
#df.dropna(axis='columns')
#df.head(5)
#df.shape # Total number of rows and columns
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df
#print(“number of duplicate rows: “, duplicate_rows_df.shape)
# Dropping the duplicates 
df = df.drop_duplicates()
df.head(5)
# Out:
#                   Dataflow Geographic Area  \
# 0  Cross-sector Indicators   Côte d'Ivoire
# 1  Cross-sector Indicators           Egypt
# 2  Cross-sector Indicators        Ethiopia
# 3  Cross-sector Indicators          Guinea
# 4  Cross-sector Indicators            Iraq
#
#                                            Indicator    Sex  Time Period  \
# 0  Percentage of girls (aged 0-14 years) who have...  Total         2016
# 1  Percentage of girls (aged 0-14 years) who have...  Total         2015
# 2  Percentage of girls (aged 0-14 years) who have...  Total         2016
# 3  Percentage of girls (aged 0-14 years) who have...  Total         2016
# 4  Percentage of girls (aged 0-14 years) who have...  Total         2018
#
#    Observation Value  Unit Multiplier Unit of Measure Observation Status  \
# 0               10.1              NaN               %         Reanalysed
# 1               14.1              NaN               %           Reported
# ...

# %%
###  How to drop NaN using jupiter notebook anaconda

# %%
# How to identify the null value NaN where the value is not equal to 0

#df.isnull().head()
df.isnull().sum()


#df[df['Unit Multiplier'].isnull()]
# Out:
# Dataflow                                                        0
# Geographic Area                                                 0
# Indicator                                                       0
# Sex                                                             0
# Time Period                                                     0
# Observation Value                                               0
# Unit Multiplier                                                39
# Unit of Measure                                                 0
# Observation Status                                              0
# Observation Confidentaility                                     0
# Lower Bound                                                    39
# Upper Bound                                                    39
# Weighted Sample Size                                           39
# Observation Footnote                                           33
# ...

# %%
df.columns
#df
# Out:
# Index(['Dataflow', 'Geographic Area', 'Indicator', 'Sex', 'Time Period',
#        'Observation Value', 'Unit Multiplier', 'Unit of Measure',
#        'Observation Status', 'Observation Confidentaility', 'Lower Bound',
#        'Upper Bound', 'Weighted Sample Size', 'Observation Footnote',
#        'Series Footnote', 'Data Source',
#        'Citation of or link to the data source', 'Custodian',
#        'Time period activity related to when the data are collected',
#        'Reference Period', 'The period of time for which data are provided',
#        'Current Age'],
#       dtype='object')

# %%
# How to identify the null value NaN where the value is equal to 0

#df.notnull().head()
df.notnull().sum()
# Out:
# Dataflow                                                       39
# Geographic Area                                                39
# Indicator                                                      39
# Sex                                                            39
# Time Period                                                    39
# Observation Value                                              39
# Unit Multiplier                                                 0
# Unit of Measure                                                39
# Observation Status                                             39
# Observation Confidentaility                                    39
# Lower Bound                                                     0
# Upper Bound                                                     0
# Weighted Sample Size                                            0
# Observation Footnote                                            6
# ...

# %%
df.shape
# Out:
# (39, 22)

# %%
# How to drop the null value ie 39 have been removed

df.dropna(how ='any').shape  
# or we can use :
# Out:
# (0, 22)

# %%
df.dropna( how ='any').tail()
# Out:
# Empty DataFrame
# Columns: [Dataflow, Geographic Area, Indicator, Sex, Time Period, Observation Value, Unit Multiplier, Unit of Measure, Observation Status, Observation Confidentaility, Lower Bound, Upper Bound, Weighted Sample Size, Observation Footnote, Series Footnote, Data Source, Citation of or link to the data source, Custodian, Time period activity related to when the data are collected, Reference Period, The period of time for which data are provided, Current Age]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.dropna(how ='all').shape
# Out:
# (39, 22)

# %%
df.dropna( how ='all').tail()
# Out:
#                    Dataflow Geographic Area  \
# 34  Cross-sector Indicators            Iraq
# 35  Cross-sector Indicators         Senegal
# 36  Cross-sector Indicators        Ethiopia
# 37  Cross-sector Indicators         Senegal
# 38  Cross-sector Indicators           Egypt
#
#                                             Indicator    Sex  Time Period  \
# 34  Percentage of women (aged 15-49 years) who thi...  Total         2018
# 35  Percentage of women (aged 15-49 years) who thi...  Total         2017
# 36  Percentage of boys and men (aged 15-49 years) ...  Total         2016
# 37  Percentage of boys and men (aged 15-49 years) ...  Total         2017
# 38  Percentage of boys and men (aged 15-49 years) ...  Total         2015
#
#     Observation Value  Unit Multiplier Unit of Measure Observation Status  \
# 34               93.6              NaN               %           Reported
# 35               80.9              NaN               %           Reported
# ...

# %%
df.dropna(how='any', thresh=1)
# Out:
#                    Dataflow              Geographic Area  \
# 0   Cross-sector Indicators                Côte d'Ivoire
# 1   Cross-sector Indicators                        Egypt
# 2   Cross-sector Indicators                     Ethiopia
# 3   Cross-sector Indicators                       Guinea
# 4   Cross-sector Indicators                         Iraq
# 5   Cross-sector Indicators                         Mali
# 6   Cross-sector Indicators                   Mauritania
# 7   Cross-sector Indicators                      Nigeria
# 8   Cross-sector Indicators                      Senegal
# 9   Cross-sector Indicators                 Sierra Leone
# 10  Cross-sector Indicators  United Republic of Tanzania
# 11  Cross-sector Indicators                         Chad
# 12  Cross-sector Indicators                Côte d'Ivoire
# 13  Cross-sector Indicators                        Egypt
# 14  Cross-sector Indicators                     Ethiopia
# ...

# %%
clean_df = df.dropna(axis='columns')
clean_df
# Out:
#                    Dataflow              Geographic Area  \
# 0   Cross-sector Indicators                Côte d'Ivoire
# 1   Cross-sector Indicators                        Egypt
# 2   Cross-sector Indicators                     Ethiopia
# 3   Cross-sector Indicators                       Guinea
# 4   Cross-sector Indicators                         Iraq
# 5   Cross-sector Indicators                         Mali
# 6   Cross-sector Indicators                   Mauritania
# 7   Cross-sector Indicators                      Nigeria
# 8   Cross-sector Indicators                      Senegal
# 9   Cross-sector Indicators                 Sierra Leone
# 10  Cross-sector Indicators  United Republic of Tanzania
# 11  Cross-sector Indicators                         Chad
# 12  Cross-sector Indicators                Côte d'Ivoire
# 13  Cross-sector Indicators                        Egypt
# 14  Cross-sector Indicators                     Ethiopia
# ...

# %%
df.dropna(subset = ['Unit Multiplier'],how='all').shape
# Out:
# (0, 22)

# %%
df.dropna(subset = ['Observation Footnote'],how='any').shape
# Out:
# (6, 22)

# %%
df.dropna(subset = ['Time period activity related to when the data are collected'],how='all').shape
# Out:
# (39, 22)

# %%
# df['Unit Multiplier'].fillna(value='Observation.Footnote', inplace=True)

# %%
#df['Unit Multiplier'].value_counts(dropna=False)

# %%
#Python Pandas Tutorial 16 | How to Fill Up NA Values | Various ways to fill missing values in python
df.fillna(method='ffill')
df.fillna(0)
# Out:
#                    Dataflow              Geographic Area  \
# 0   Cross-sector Indicators                Côte d'Ivoire
# 1   Cross-sector Indicators                        Egypt
# 2   Cross-sector Indicators                     Ethiopia
# 3   Cross-sector Indicators                       Guinea
# 4   Cross-sector Indicators                         Iraq
# 5   Cross-sector Indicators                         Mali
# 6   Cross-sector Indicators                   Mauritania
# 7   Cross-sector Indicators                      Nigeria
# 8   Cross-sector Indicators                      Senegal
# 9   Cross-sector Indicators                 Sierra Leone
# 10  Cross-sector Indicators  United Republic of Tanzania
# 11  Cross-sector Indicators                         Chad
# 12  Cross-sector Indicators                Côte d'Ivoire
# 13  Cross-sector Indicators                        Egypt
# 14  Cross-sector Indicators                     Ethiopia
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#Time.Period = [2016 2015 2016 2016 2018 2015 2015 2017 2017 2017] 
hist(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5d794d94234c> in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 #Time.Period = [2016 2015 2016 2016 2018 2015 2015 2017 2017 2017]
# ----> 4 hist(df)
#
# NameError: name 'hist' is not defined
